# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# switch to the github folder
% cd /content/drive/MyDrive/Colab\ Notebooks/colab
# Out:
# /content/drive/MyDrive/Colab Notebooks/colab

# %%
# pull the gitlab, to make sure it's up to date
! git pull origin dev
# Out:
# From https://github.com/KoichiFunaya/colab
#  * branch            dev        -> FETCH_HEAD
# Updating 9e81b03..e58076c
# Checking out files: 100% (9/9), done.
# Fast-forward
#  .ipynb_checkpoints/News_Analysis-checkpoint.ipynb  |  586 ++++++---
#  .ipynb_checkpoints/README-checkpoint.md            |    2 +
#  .../Spam_Classification-checkpoint.ipynb           | 1160 +++++++++++++++++
#  .ipynb_checkpoints/config-checkpoint.ini           |   46 +-
#  News_Analysis.ipynb                                |  467 ++++---
#  Spam_Classification.ipynb                          | 1160 +++++++++++++++++
#  config.ini                                         |   46 +-
#  .../News_Analysis-checkpoint.ipynb                 | 1325 ++++++++++++++++++++
#  outdated/News_Analysis.ipynb                       | 1325 ++++++++++++++++++++
#  9 files changed, 5770 insertions(+), 347 deletions(-)
#  create mode 100644 .ipynb_checkpoints/README-checkpoint.md
#  create mode 100644 .ipynb_checkpoints/Spam_Classification-checkpoint.ipynb
#  create mode 100644 Spam_Classification.ipynb
#  create mode 100644 outdated/.ipynb_checkpoints/News_Analysis-checkpoint.ipynb
#  create mode 100644 outdated/News_Analysis.ipynb

# %%
#! git config --global user.name KoichiFunaya
#! git config --global user.email koichi.funaya@neclab.eu
#! git config --global github.token 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
! git add --all
! git commit -m "modified at Google Colab environment"
! git push https://KoichiFunaya@github.com dev
# Out:
# On branch dev
# nothing to commit, working tree clean
# fatal: repository 'https://KoichiFunaya@github.com/' not found
